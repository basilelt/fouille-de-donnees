# %% [markdown]
#  ## **Packages Python** *(Numpy, Pandas, Matplotlib, Seaborn, Scikit-learn)*
#
# Auteur : [Germain Forestier](https://germain-forestier.info/)
#
# *  **Numpy** : destiné à manipuler des matrices ou tableaux ainsi que des fonctions mathématiques opérant sur ces tableaux
# * **Pandas** : propose des structures de données et des opérations de manipulation de tableaux numériques et de séries temporelles
# * **Matplotlib** : permet de tracer et visualiser des données sous forme de graphiques
# * **Seaborn** : complément à `matplotlib` pour la visualisation de données
# * **Scikit-learn** : destiné à l'apprentissage automatique

# %% [markdown]
# ### Numpy
#
# * Numerical Python
# * Alternative aux listes Python : Numpy Array
# * Facilite les calculs sur des tableaux
# * Simple et rapide

# %%
# numpy
import numpy as np

np_height = np.array([1.73, 1.68, 1.71, 1.89, 1.79])
np_weight = np.array([65.4, 59.2, 63.6, 88.4, 68.7])

bmi = np_weight / np_height ** 2

print(bmi)
# Out:
# [21.85171573 20.97505669 21.75028214 24.7473475  21.44127836]

# %% [markdown]
# ### Pandas
#
# * Package haut-niveau pour la manipulation de données
# * Basé sur Numpy
# * Permet de gérer des données de différents types
# * L'objet `DataFrame` permet de manipuler les données

# %%
# import
import numpy as np
import pandas as pd

df = pd.DataFrame({'A' : 1.,
'B' : pd.Timestamp('20130102'),
'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
'D' : np.array([3] * 4,dtype='int32'),
'E' : pd.Categorical(["test","train","test","train"]),
'F' : 'foo' })

print(df)
print(df.dtypes)
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %% [markdown]
# * L'objet `DataFrame` permet de faire de la sélection de données
# * La fonction `loc` permet de recherche par nom
# * La fonction `iloc` permet de recherche par index

# %%
# columns/rows selection
print(df['A'])
print(df[['A','B']])
print(df[0:3])

# name search
print(df.loc[:,['A','B']])

# index search
print(df.iloc[3])
print(df.iloc[1:3])
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# Name: A, dtype: float64
#      A          B
# 0  1.0 2013-01-02
# 1  1.0 2013-01-02
# 2  1.0 2013-01-02
# 3  1.0 2013-01-02
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
#      A          B
# 0  1.0 2013-01-02
# 1  1.0 2013-01-02
# 2  1.0 2013-01-02
# 3  1.0 2013-01-02
# A                    1.0
# B    2013-01-02 00:00:00
# C                    1.0
# D                      3
# E                  train
# F                    foo
# Name: 3, dtype: object
#      A          B    C  D      E    F
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo

# %% [markdown]
# Résumé de la sélection dans les tableaux pandas :
#
# <img width='500px' src ='https://www.shanelynn.ie/wp-content/uploads/2016/10/Pandas-selections-and-indexing.png' />
#
# [source](https://www.shanelynn.ie/select-pandas-dataframe-rows-and-columns-using-iloc-loc-and-ix/)

# %% [markdown]
# ### Lire des données
#
# * Il est souvent nécessaire de lire des données depuis des fichiers afin de les traiter et de pouvoir construire des modèles prédictifs
# * La fonction `genfromtxt()` de Numpy permet de lire des fichiers, mais uniquement avec des attributs de même type
# * La fonction `read_csv()` de Pandas permet de lire des fichiers avec des types d'attributs différents

# %%
# lecture de données avec Numpy
import numpy as np
data = np.genfromtxt('http://germain-forestier.info/dataset/iris.csv', delimiter=',', skip_header=True)

# lecture de données avec Pandas
import pandas as pd
df = pd.read_csv('http://germain-forestier.info/dataset/iris.csv', header=0)

# %% [markdown]
# ### Matplotlib
# Visualisation de données :
# * Très important en analyse de données
# * Permet d'explorer les données
# * Permet de rapporter des résultats
# * Matplotlib permet de facilement visualiser des données

# %%
import matplotlib.pyplot as plt

year = [1950, 1970, 1990, 2010]
pop = [2.519, 3.692, 5.263, 6.972]

plt.plot(year, pop)
plt.show()

# %%
import matplotlib.pyplot as plt

year = [1950, 1970, 1990, 2010]
pop = [2.519, 3.692, 5.263, 6.972]

plt.scatter(year, pop)
plt.show()

# %%
import matplotlib.pyplot as plt

year = [1950, 1970, 1990, 2010]
pop = [2.519, 3.692, 5.263, 6.972]

plt.title('Evolution de la population')
plt.xlabel('Années')
plt.ylabel('Milliards d\'habitans')
plt.scatter(year, pop)
plt.show()

# %% [markdown]
# ### **Exercice** : *Visualisation de données*
#
# * Importer les données `iris` à l'aide de `read_csv()` de Pandas
# * Générer le graphique suivant à l'aide de `matplotlib` (choisir deux caractéristiques) :
#
# <img src="https://germain-forestier.info/dataset/packages/iris3.png" />

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('http://germain-forestier.info/dataset/iris.csv', header=0)

# Votre code ici
# print(df.head)
# print(df["sepal_length"].head)

plt.title('Iris')
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
plt.scatter(df[df['species'] == 'setosa']["sepal_length"], df[df['species'] == 'setosa']["sepal_width"], label='setosa')
plt.scatter(df[df['species'] == 'versicolor']["sepal_length"], df[df['species'] == 'versicolor']["sepal_width"], label='versicolor')
plt.scatter(df[df['species'] == 'virginica']["sepal_length"], df[df['species'] == 'virginica']["sepal_width"], label='virginica')
plt.legend()
plt.show()

# %% [markdown]
#  ### Corrigé

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('http://germain-forestier.info/dataset/iris.csv', header=0)

subset = df[df['species'] == 'setosa']
plt.scatter(subset['sepal_length'], subset['sepal_width'], label='setosa')

subset = df[df['species'] == 'versicolor']
plt.scatter(subset['sepal_length'], subset['sepal_width'], label='versicolor')

subset = df[df['species'] == 'virginica']
plt.scatter(subset['sepal_length'], subset['sepal_width'], label='virginica')

plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
plt.title('Iris')
plt.legend()
plt.show()

# %% [markdown]
# ### Seaborn
#
# * Le package Seaborn est une alternative à Matplotlib
# * Rajoute des fonctionnalités
# * Permet de faire des visualisations avancées

# %%
import seaborn as sns
import pandas as pd

df = pd.read_csv('http://germain-forestier.info/dataset/iris.csv', header=0)

ax = sns.pairplot(df, hue='species', height=1.5)
plt.show()

# %% [markdown]
# ### Validation (train/test)
#
# * Afin de pouvoir valider un modèle, il est important de pouvoir tester sa capacité à faire de bonnes prédictions
# * On évite de tester un modèle sur les mêmes données utilisées pour construire le modèle
# * Si on utilise les mêmes données, les performances auront tendance à être surévaluées et on ne teste pas la capacité de généralisation
# * La méthode la plus classique consiste à découper le jeu de données en deux ensembles, un pour l’apprentissage (*train*) et un pour l’évaluation (*test*)

# %% [markdown]
# ### Validation (train/test)
#
# * On garde 80% des données pour l’apprentissage et 20% pour le test :

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('http://germain-forestier.info/dataset/iris.csv', header=0)
mask = np.random.rand(len(df)) < 0.8
df_train = df[mask]
df_test = df[~mask]

# %% [markdown]
# * Il faut faire attention à la distribution des classes (nombre d’éléments de chaque classe qui peut être différent)
# * Afin de conserver la même distribution, on parle de stratification

# %%
import matplotlib.pyplot as plt

def plotdata(df, title):
  subset = df[df['species'] == 'setosa']
  plt.scatter(subset['sepal_length'], subset['sepal_width'], label='setosa')

  subset = df[df['species'] == 'versicolor']
  plt.scatter(subset['sepal_length'], subset['sepal_width'], label='versicolor')

  subset = df[df['species'] == 'virginica']
  plt.scatter(subset['sepal_length'], subset['sepal_width'], label='virginica')

  plt.xlabel('sepal_length')
  plt.ylabel('sepal_width')
  plt.title(title)
  plt.legend()
  plt.show()

plotdata(df_train,'Iris train')
plotdata(df_test, 'Iris test')

# %% [markdown]
# ### Matrice de confusion
#
# *   Matrice de comparaison entre les prédictions et la vraie classe des objets
# *   Permet d’évaluer les performances d’une méthode de classification
# *   Permet de mettre en évidence les confusions (erreurs) entre les classes

# %% [markdown]
# ### Validation croisée (cross validation)
#
# *   Alternative au découpage train / test
# *   Le jeu de données est coupé en K sous ensembles
# *   K-1 ensembles utilisés pour le train, 1 ensemble utilisé pour le test
# *   Chaque ensemble est utilisé une fois pour le test

# %% [markdown]
# <img width=300px src='https://www.researchgate.net/profile/B_Aksasse/publication/326866871/figure/fig2/AS:669601385947145@1536656819574/K-fold-cross-validation-In-addition-we-outline-an-overview-of-the-different-metrics-used.jpg' />
#
# [source](https://raw.githubusercontent.com/qingkaikong/)

# %% [markdown]
# ### Scikit-learn
#
# * Scikit-learn contient la majorité des algorithmes de fouille de données
# * Il offre également de nombreux outils pour l'évaluation des modèles
# * Scikit-learn décompose les données et la variable à prédire (*target*)

# %%
from sklearn.model_selection import train_test_split

df = pd.read_csv('http://germain-forestier.info/dataset/iris.csv', header=0)
X = df[['sepal_length','sepal_width','petal_length','petal_width']]
y = df[['species']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

print(X_train.head(3))
print('\n')
print(X_test.head(3))
print('\n')
print(y_train.head(3))
print('\n')
print(y_test.head(3))
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 17            5.1          3.5           1.4          0.3
# 125           7.2          3.2           6.0          1.8
# 122           7.7          2.8           6.7          2.0
#
#
#      sepal_length  sepal_width  petal_length  petal_width
# 77            6.7          3.0           5.0          1.7
# 99            5.7          2.8           4.1          1.3
# 118           7.7          2.6           6.9          2.3
#
#
#        species
# 17      setosa
# 125  virginica
# 122  virginica
#
#
#         species
# 77   versicolor
# 99   versicolor
# 118   virginica

# %% [markdown]
# *   Scikit-learn permet également de calculer la matrice de confusion et
# d’évaluer les performances des modèles

# %%
from sklearn.metrics import confusion_matrix, classification_report, precision_score

real = ['setosa','setosa','versicolor','versicolor','virginica','virginica']
pred = ['setosa','setosa','versicolor','virginica','virginica','virginica']

print(confusion_matrix(real, pred))
print(classification_report(real , pred))
print(precision_score(real , pred, average='micro'))
# Out:
# [[2 0 0]
#  [0 1 1]
#  [0 0 2]]
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         2
#   versicolor       1.00      0.50      0.67         2
#    virginica       0.67      1.00      0.80         2
#
#     accuracy                           0.83         6
#    macro avg       0.89      0.83      0.82         6
# weighted avg       0.89      0.83      0.82         6
#
# 0.8333333333333334

# %% [markdown]
# ### **Exercice** : *Un premier classifieur*
#
# * A l'aider de la visualisation de données du jeu de données Iris, créer un classifieur simple à base de seuils afin de classer les différents types d'iris
# * Évaluer les performances de votre classifieur sur toutes les données
# * Faire un graphique pour illustrer la frontière des classes

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# lecture des données
df = pd.read_csv('http://germain-forestier.info/dataset/iris.csv', header=0)

# écrire un classifieur à base de seuils
df['pred'] = 'setosa'
df.loc[df['petal_width'] > 0.8,'pred'] = 'versicolor'
df.loc[df['petal_width'] > 1.7,'pred'] = 'virginica'

print(confusion_matrix(df['species'], df['pred']))
print(classification_report(df['species'], df['pred']))
# Out:
# [[50  0  0]
#  [ 0 49  1]
#  [ 0  5 45]]
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        50
#   versicolor       0.91      0.98      0.94        50
#    virginica       0.98      0.90      0.94        50
#
#     accuracy                           0.96       150
#    macro avg       0.96      0.96      0.96       150
# weighted avg       0.96      0.96      0.96       150

# %%
import pandas as pd
import matplotlib.pyplot as plt

# lecture des données
df = pd.read_csv('http://germain-forestier.info/dataset/iris.csv', header=0)

# afficher la frontière des classes
groups = df.groupby('species')

fig, ax = plt.subplots()
ax.margins(0.05)
for name, group in groups:
    ax.plot(group.petal_length, group.petal_width, marker='o', linestyle='', ms=4, label=name)
plt.xlabel("petal_length")
plt.ylabel("petal_width")
plt.title("Iris dataset")
plt.axhline(0.8)
plt.axhline(1.7)
ax.legend()
plt.show()

# %% [markdown]
#  ### Corrigé

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# lecture des données
df = pd.read_csv('http://germain-forestier.info/dataset/iris.csv', header=0)

df['pred'] = 'setosa'
df.loc[df['petal_width'] > 0.8,'pred'] = 'versicolor'
df.loc[df['petal_width'] > 1.7,'pred'] = 'virginica'

print(confusion_matrix(df['species'], df['pred']))
print(classification_report(df['species'], df['pred']))
# Out:
# [[50  0  0]
#  [ 0 49  1]
#  [ 0  5 45]]
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        50
#   versicolor       0.91      0.98      0.94        50
#    virginica       0.98      0.90      0.94        50
#
#     accuracy                           0.96       150
#    macro avg       0.96      0.96      0.96       150
# weighted avg       0.96      0.96      0.96       150

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('http://germain-forestier.info/dataset/iris.csv', header=0)
groups = df.groupby('species')

fig, ax = plt.subplots()
ax.margins(0.05)
for name, group in groups:
    ax.plot(group.petal_length, group.petal_width, marker='o', linestyle='', ms=4, label=name)
plt.xlabel("petal_length")
plt.ylabel("petal_width")
plt.title("Iris dataset")
plt.axhline(0.8)
plt.axhline(1.7)
ax.legend()
plt.show()
